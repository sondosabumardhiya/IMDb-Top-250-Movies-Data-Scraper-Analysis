# %% [markdown]
# # Assignment Data Eng.

# %% [markdown]
# # Task One

# %% [markdown]
# ## Extracting Links / Sending Request

# %%
import requests
from bs4 import BeautifulSoup
import json

headers = {'Accept': '/', 'Connection': 'keep-alive', 'User-Agent': 'Mozilla/5.0 (Windows NT 6.0) AppleWebKit/537.36 (KHTML,like Gecko) Chrome/70.0.3538.110 Safari/537.36', 'Accept-Language':'en-US;q=0.5,en;q=0.3', 'Cache-Control': 'max-age=0', 'Upgrade-Insecure-Requests': '1'}

response = requests.get('https://www.imdb.com/chart/top/', headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

data = json.loads(soup.find('script', {'type':"application/ld+json"}).text)
print(len(data['itemListElement']))
for item in data['itemListElement'][:250]:
    print(item['item']['url'])
# Out:
# 250
# https://www.imdb.com/title/tt0111161/
# https://www.imdb.com/title/tt0068646/
# https://www.imdb.com/title/tt0468569/
# https://www.imdb.com/title/tt0071562/
# https://www.imdb.com/title/tt0050083/
# https://www.imdb.com/title/tt0167260/
# https://www.imdb.com/title/tt0108052/
# https://www.imdb.com/title/tt0110912/
# https://www.imdb.com/title/tt0120737/
# https://www.imdb.com/title/tt0060196/
# https://www.imdb.com/title/tt0109830/
# https://www.imdb.com/title/tt0167261/
# https://www.imdb.com/title/tt0137523/
# https://www.imdb.com/title/tt1375666/
# https://www.imdb.com/title/tt0080684/
# https://www.imdb.com/title/tt0133093/
# https://www.imdb.com/title/tt0099685/
# https://www.imdb.com/title/tt0073486/
# https://www.imdb.com/title/tt0816692/
# https://www.imdb.com/title/tt0114369/
# https://www.imdb.com/title/tt0038650/
# https://www.imdb.com/title/tt0047478/
# https://www.imdb.com/title/tt0102926/
# https://www.imdb.com/title/tt0120815/
# https://www.imdb.com/title/tt0317248/
# https://www.imdb.com/title/tt0120689/
# https://www.imdb.com/title/tt0118799/
# https://www.imdb.com/title/tt0103064/
# https://www.imdb.com/title/tt0076759/
# https://www.imdb.com/title/tt0088763/
# https://www.imdb.com/title/tt0245429/
# https://www.imdb.com/title/tt0253474/
# https://www.imdb.com/title/tt6751668/
# https://www.imdb.com/title/tt0172495/
# https://www.imdb.com/title/tt0054215/
# https://www.imdb.com/title/tt0110357/
# https://www.imdb.com/title/tt0407887/
# https://www.imdb.com/title/tt0095327/
# https://www.imdb.com/title/tt9362722/
# https://www.imdb.com/title/tt2582802/
# https://www.imdb.com/title/tt0120586/
# https://www.imdb.com/title/tt0482571/
# https://www.imdb.com/title/tt0110413/
# https://www.imdb.com/title/tt0056058/
# https://www.imdb.com/title/tt0034583/
# https://www.imdb.com/title/tt0114814/
# https://www.imdb.com/title/tt1675434/
# https://www.imdb.com/title/tt0095765/
# https://www.imdb.com/title/tt15239678/
# https://www.imdb.com/title/tt0027977/
# https://www.imdb.com/title/tt0078748/
# https://www.imdb.com/title/tt0047396/
# https://www.imdb.com/title/tt0064116/
# https://www.imdb.com/title/tt1853728/
# https://www.imdb.com/title/tt0021749/
# https://www.imdb.com/title/tt0078788/
# https://www.imdb.com/title/tt0209144/
# https://www.imdb.com/title/tt0910970/
# https://www.imdb.com/title/tt0082971/
# https://www.imdb.com/title/tt0405094/
# https://www.imdb.com/title/tt23849204/
# https://www.imdb.com/title/tt4154756/
# https://www.imdb.com/title/tt0043014/
# https://www.imdb.com/title/tt4633694/
# https://www.imdb.com/title/tt0050825/
# https://www.imdb.com/title/tt0051201/
# https://www.imdb.com/title/tt0081505/
# https://www.imdb.com/title/tt0032553/
# https://www.imdb.com/title/tt0090605/
# https://www.imdb.com/title/tt0361748/
# https://www.imdb.com/title/tt1345836/
# https://www.imdb.com/title/tt2380307/
# https://www.imdb.com/title/tt0086879/
# https://www.imdb.com/title/tt0114709/
# https://www.imdb.com/title/tt0057012/
# https://www.imdb.com/title/tt0364569/
# https://www.imdb.com/title/tt0169547/
# https://www.imdb.com/title/tt4154796/
# https://www.imdb.com/title/tt0119217/
# https://www.imdb.com/title/tt0082096/
# https://www.imdb.com/title/tt0112573/
# https://www.imdb.com/title/tt0119698/
# https://www.imdb.com/title/tt5311514/
# https://www.imdb.com/title/tt0057565/
# https://www.imdb.com/title/tt7286456/
# https://www.imdb.com/title/tt1187043/
# https://www.imdb.com/title/tt0087843/
# https://www.imdb.com/title/tt0045152/
# https://www.imdb.com/title/tt8267604/
# https://www.imdb.com/title/tt0091251/
# https://www.imdb.com/title/tt0180093/
# https://www.imdb.com/title/tt0435761/
# https://www.imdb.com/title/tt0086190/
# https://www.imdb.com/title/tt2106476/
# https://www.imdb.com/title/tt0338013/
# https://www.imdb.com/title/tt0044741/
# https://www.imdb.com/title/tt0062622/
# https://www.imdb.com/title/tt0105236/
# https://www.imdb.com/title/tt0056172/
# https://www.imdb.com/title/tt0053604/
# https://www.imdb.com/title/tt1255953/
# https://www.imdb.com/title/tt0086250/
# https://www.imdb.com/title/tt0053125/
# https://www.imdb.com/title/tt0036775/
# https://www.imdb.com/title/tt0033467/
# https://www.imdb.com/title/tt0022100/
# https://www.imdb.com/title/tt0113277/
# https://www.imdb.com/title/tt0052357/
# https://www.imdb.com/title/tt0093058/
# https://www.imdb.com/title/tt15398776/
# https://www.imdb.com/title/tt1049413/
# https://www.imdb.com/title/tt0211915/
# https://www.imdb.com/title/tt0066921/
# https://www.imdb.com/title/tt0056592/
# https://www.imdb.com/title/tt1832382/
# https://www.imdb.com/title/tt0070735/
# https://www.imdb.com/title/tt0095016/
# https://www.imdb.com/title/tt0097576/
# https://www.imdb.com/title/tt0986264/
# https://www.imdb.com/title/tt0017136/
# https://www.imdb.com/title/tt0208092/
# https://www.imdb.com/title/tt8579674/
# https://www.imdb.com/title/tt0119488/
# https://www.imdb.com/title/tt0040522/
# https://www.imdb.com/title/tt0363163/
# https://www.imdb.com/title/tt0075314/
# https://www.imdb.com/title/tt8503618/
# https://www.imdb.com/title/tt5074352/
# https://www.imdb.com/title/tt0993846/
# https://www.imdb.com/title/tt0372784/
# https://www.imdb.com/title/tt0059578/
# https://www.imdb.com/title/tt6966692/
# https://www.imdb.com/title/tt0053291/
# https://www.imdb.com/title/tt0120382/
# https://www.imdb.com/title/tt0055031/
# https://www.imdb.com/title/tt0012349/
# https://www.imdb.com/title/tt10272386/
# https://www.imdb.com/title/tt1130884/
# https://www.imdb.com/title/tt0042192/
# https://www.imdb.com/title/tt0469494/
# https://www.imdb.com/title/tt0107290/
# https://www.imdb.com/title/tt0112641/
# https://www.imdb.com/title/tt1745960/
# https://www.imdb.com/title/tt0167404/
# https://www.imdb.com/title/tt0089881/
# https://www.imdb.com/title/tt0457430/
# https://www.imdb.com/title/tt0477348/
# https://www.imdb.com/title/tt0105695/
# https://www.imdb.com/title/tt0084787/
# https://www.imdb.com/title/tt0268978/
# https://www.imdb.com/title/tt0266697/
# https://www.imdb.com/title/tt0040897/
# https://www.imdb.com/title/tt0055630/
# https://www.imdb.com/title/tt29623480/
# https://www.imdb.com/title/tt1392214/
# https://www.imdb.com/title/tt0266543/
# https://www.imdb.com/title/tt0057115/
# https://www.imdb.com/title/tt0071853/
# https://www.imdb.com/title/tt0347149/
# https://www.imdb.com/title/tt0080678/
# https://www.imdb.com/title/tt0042876/
# https://www.imdb.com/title/tt0046912/
# https://www.imdb.com/title/tt0031381/
# https://www.imdb.com/title/tt0071315/
# https://www.imdb.com/title/tt1305806/
# https://www.imdb.com/title/tt0120735/
# https://www.imdb.com/title/tt2096673/
# https://www.imdb.com/title/tt0434409/
# https://www.imdb.com/title/tt16492678/
# https://www.imdb.com/title/tt5027774/
# https://www.imdb.com/title/tt0081398/
# https://www.imdb.com/title/tt4729430/
# https://www.imdb.com/title/tt0050212/
# https://www.imdb.com/title/tt0117951/
# https://www.imdb.com/title/tt0264464/
# https://www.imdb.com/title/tt0116282/
# https://www.imdb.com/title/tt1291584/
# https://www.imdb.com/title/tt10872600/
# https://www.imdb.com/title/tt1205489/
# https://www.imdb.com/title/tt1201607/
# https://www.imdb.com/title/tt0405159/
# https://www.imdb.com/title/tt0096283/
# https://www.imdb.com/title/tt1392190/
# https://www.imdb.com/title/tt0052618/
# https://www.imdb.com/title/tt0118849/
# https://www.imdb.com/title/tt0072684/
# https://www.imdb.com/title/tt2024544/
# https://www.imdb.com/title/tt0083658/
# https://www.imdb.com/title/tt0112471/
# https://www.imdb.com/title/tt2278388/
# https://www.imdb.com/title/tt2119532/
# https://www.imdb.com/title/tt0097165/
# https://www.imdb.com/title/tt2267998/
# https://www.imdb.com/title/tt0353969/
# https://www.imdb.com/title/tt26548265/
# https://www.imdb.com/title/tt0107207/
# https://www.imdb.com/title/tt0015864/
# https://www.imdb.com/title/tt0198781/
# https://www.imdb.com/title/tt3011894/
# https://www.imdb.com/title/tt0382932/
# https://www.imdb.com/title/tt0892769/
# https://www.imdb.com/title/tt0077416/
# https://www.imdb.com/title/tt0073195/
# https://www.imdb.com/title/tt0017925/
# https://www.imdb.com/title/tt0015324/
# https://www.imdb.com/title/tt0978762/
# https://www.imdb.com/title/tt0047296/
# https://www.imdb.com/title/tt0046268/
# https://www.imdb.com/title/tt1950186/
# https://www.imdb.com/title/tt0031679/
# https://www.imdb.com/title/tt0050986/
# https://www.imdb.com/title/tt0041959/
# https://www.imdb.com/title/tt3315342/
# https://www.imdb.com/title/tt0075148/
# https://www.imdb.com/title/tt0046438/
# https://www.imdb.com/title/tt0118715/
# https://www.imdb.com/title/tt0050976/
# https://www.imdb.com/title/tt1895587/
# https://www.imdb.com/title/tt3170832/
# https://www.imdb.com/title/tt0088247/
# https://www.imdb.com/title/tt0395169/
# https://www.imdb.com/title/tt0091763/
# https://www.imdb.com/title/tt0325980/
# https://www.imdb.com/title/tt0113247/
# https://www.imdb.com/title/tt0381681/
# https://www.imdb.com/title/tt15097216/
# https://www.imdb.com/title/tt0036868/
# https://www.imdb.com/title/tt0019254/
# https://www.imdb.com/title/tt0070047/
# https://www.imdb.com/title/tt0032138/
# https://www.imdb.com/title/tt0317705/
# https://www.imdb.com/title/tt1979320/
# https://www.imdb.com/title/tt0074958/
# https://www.imdb.com/title/tt0092005/
# https://www.imdb.com/title/tt1028532/
# https://www.imdb.com/title/tt0059742/
# https://www.imdb.com/title/tt0049902/
# https://www.imdb.com/title/tt0476735/
# https://www.imdb.com/title/tt4016934/
# https://www.imdb.com/title/tt0035446/
# https://www.imdb.com/title/tt0758758/
# https://www.imdb.com/title/tt0058946/
# https://www.imdb.com/title/tt0129167/
# https://www.imdb.com/title/tt0032551/
# https://www.imdb.com/title/tt0107048/
# https://www.imdb.com/title/tt0245712/
# https://www.imdb.com/title/tt0032976/
# https://www.imdb.com/title/tt1454029/
# https://www.imdb.com/title/tt0061512/
# https://www.imdb.com/title/tt5323662/

# %% [markdown]
# ## Extracting full cast and crew

# %%
import pandas as pd
import time


headers = {
    'Accept': '/',
    'Connection': 'keep-alive',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.0) AppleWebKit/537.36 (KHTML,like Gecko) Chrome/70.0.3538.110 Safari/537.36',
}


def fetch_cast_and_crew(movie_url, movie_id):
    cast_and_crew = []
    try:
        
        response = requests.get(movie_url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')

        
        full_cast_link = None
        for link in soup.find_all("a", href=True):
            if "fullcredits" in link['href']:
                full_cast_link = "https://www.imdb.com" + link['href']
                break

        if full_cast_link:
            
            cast_response = requests.get(full_cast_link, headers=headers)
            cast_soup = BeautifulSoup(cast_response.content, 'html.parser')

            
            cast_table = cast_soup.find("table", class_="cast_list")
            if cast_table:
                for row in cast_table.find_all("tr")[1:]:  
                    cols = row.find_all("td")
                    if len(cols) >= 2:
                        name = cols[1].text.strip()
                        character = cols[3].text.strip() if len(cols) > 3 else "N/A"
                        cast_and_crew.append({
                            "Movie_ID": movie_id,
                            "Name": name,
                            "Role Type": "Actor",
                            "Character/Position": character
                        })

           
            produced_by_section = cast_soup.find("h4", string="Produced by")
            if produced_by_section:
                for producer in produced_by_section.find_next("ul").find_all("li"):
                    name = producer.text.strip()
                    cast_and_crew.append({
                        "Movie_ID": movie_id,
                        "Name": name,
                        "Role Type": "Producer",
                        "Character/Position": "N/A"
                    })
        else:
            print(f"No Full Cast & Crew link found for {movie_url}")
    
    except Exception as e:
        print(f"Error scraping cast & crew for {movie_url}: {e}")

    return cast_and_crew



movie_urls = [
    "https://www.imdb.com/title/tt0111161/",  
    "https://www.imdb.com/title/tt0068646/", 
    
]


movie_urls = [
    f"https://www.imdb.com/title/tt{1000000 + i}/" for i in range(1, 251)
]


full_cast_and_crew_list = []

 
for movie_url in movie_urls:
    movie_id = movie_url.split("/")[4] 
    print(f"Fetching cast and crew for movie ID {movie_id} from {movie_url}")
    
    
    cast_and_crew = fetch_cast_and_crew(movie_url, movie_id)
    
    
    full_cast_and_crew_list.extend(cast_and_crew)
    
    
    time.sleep(1)


full_cast_and_crew_df = pd.DataFrame(full_cast_and_crew_list)


print(full_cast_and_crew_df.head())


full_cast_and_crew_df.to_csv("full_cast_and_crew.csv", index=False)
# Out:
# Fetching cast and crew for movie ID tt1000001 from https://www.imdb.com/title/tt1000001/
# Fetching cast and crew for movie ID tt1000002 from https://www.imdb.com/title/tt1000002/
# No Full Cast & Crew link found for https://www.imdb.com/title/tt1000002/
# Fetching cast and crew for movie ID tt1000003 from https://www.imdb.com/title/tt1000003/
# Fetching cast and crew for movie ID tt1000004 from https://www.imdb.com/title/tt1000004/
# Fetching cast and crew for movie ID tt1000005 from https://www.imdb.com/title/tt1000005/
# Fetching cast and crew for movie ID tt1000006 from https://www.imdb.com/title/tt1000006/
# Fetching cast and crew for movie ID tt1000007 from https://www.imdb.com/title/tt1000007/
# Fetching cast and crew for movie ID tt1000008 from https://www.imdb.com/title/tt1000008/
# Fetching cast and crew for movie ID tt1000009 from https://www.imdb.com/title/tt1000009/
# Fetching cast and crew for movie ID tt1000010 from https://www.imdb.com/title/tt1000010/
# Fetching cast and crew for movie ID tt1000011 from https://www.imdb.com/title/tt1000011/
# Fetching cast and crew for movie ID tt1000012 from https://www.imdb.com/title/tt1000012/
# Fetching cast and crew for movie ID tt1000013 from https://www.imdb.com/title/tt1000013/
# Fetching cast and crew for movie ID tt1000014 from https://www.imdb.com/title/tt1000014/
# Fetching cast and crew for movie ID tt1000015 from https://www.imdb.com/title/tt1000015/
# Fetching cast and crew for movie ID tt1000016 from https://www.imdb.com/title/tt1000016/
# Fetching cast and crew for movie ID tt1000017 from https://www.imdb.com/title/tt1000017/
# Fetching cast and crew for movie ID tt1000018 from https://www.imdb.com/title/tt1000018/
# Fetching cast and crew for movie ID tt1000019 from https://www.imdb.com/title/tt1000019/
# Fetching cast and crew for movie ID tt1000020 from https://www.imdb.com/title/tt1000020/
# Fetching cast and crew for movie ID tt1000021 from https://www.imdb.com/title/tt1000021/
# Fetching cast and crew for movie ID tt1000022 from https://www.imdb.com/title/tt1000022/
# Fetching cast and crew for movie ID tt1000023 from https://www.imdb.com/title/tt1000023/
# Fetching cast and crew for movie ID tt1000024 from https://www.imdb.com/title/tt1000024/
# Fetching cast and crew for movie ID tt1000025 from https://www.imdb.com/title/tt1000025/
# Fetching cast and crew for movie ID tt1000026 from https://www.imdb.com/title/tt1000026/
# No Full Cast & Crew link found for https://www.imdb.com/title/tt1000026/
# Fetching cast and crew for movie ID tt1000027 from https://www.imdb.com/title/tt1000027/
# No Full Cast & Crew link found for https://www.imdb.com/title/tt1000027/
# Fetching cast and crew for movie ID tt1000028 from https://www.imdb.com/title/tt1000028/
# No Full Cast & Crew link found for https://www.imdb.com/title/tt1000028/
# Fetching cast and crew for movie ID tt1000029 from https://www.imdb.com/title/tt1000029/
# No Full Cast & Crew link found for https://www.imdb.com/title/tt1000029/
# Fetching cast and crew for movie ID tt1000030 from https://www.imdb.com/title/tt1000030/
# Fetching cast and crew for movie ID tt1000031 from https://www.imdb.com/title/tt1000031/
# Fetching cast and crew for movie ID tt1000032 from https://www.imdb.com/title/tt1000032/
# No Full Cast & Crew link found for https://www.imdb.com/title/tt1000032/
# Fetching cast and crew for movie ID tt1000033 from https://www.imdb.com/title/tt1000033/
# No Full Cast & Crew link found for https://www.imdb.com/title/tt1000033/
# Fetching cast and crew for movie ID tt1000034 from https://www.imdb.com/title/tt1000034/
# No Full Cast & Crew link found for https://www.imdb.com/title/tt1000034/
# Fetching cast and crew for movie ID tt1000035 from https://www.imdb.com/title/tt1000035/
# Fetching cast and crew for movie ID tt1000036 from https://www.imdb.com/title/tt1000036/
# Fetching cast and crew for movie ID tt1000037 from https://www.imdb.com/title/tt1000037/
# Fetching cast and crew for movie ID tt1000038 from https://www.imdb.com/title/tt1000038/
# Fetching cast and crew for movie ID tt1000039 from https://www.imdb.com/title/tt1000039/
# Fetching cast and crew for movie ID tt1000040 from https://www.imdb.com/title/tt1000040/
# No Full Cast & Crew link found for https://www.imdb.com/title/tt1000040/
# Fetching cast and crew for movie ID tt1000041 from https://www.imdb.com/title/tt1000041/
# Fetching cast and crew for movie ID tt1000042 from https://www.imdb.com/title/tt1000042/
# No Full Cast & Crew link found for https://www.imdb.com/title/tt1000042/
# Fetching cast and crew for movie ID tt1000043 from https://www.imdb.com/title/tt1000043/
# No Full Cast & Crew link found for https://www.imdb.com/title/tt1000043/
# Fetching cast and crew for movie ID tt1000044 from https://www.imdb.com/title/tt1000044/
# No Full Cast & Crew link found for https://www.imdb.com/title/tt1000044/
# Fetching cast and crew for movie ID tt1000045 from https://www.imdb.com/title/tt1000045/
# Fetching cast and crew for movie ID tt1000046 from https://www.imdb.com/title/tt1000046/
# Fetching cast and crew for movie ID tt1000047 from https://www.imdb.com/title/tt1000047/
# Fetching cast and crew for movie ID tt1000048 from https://www.imdb.com/title/tt1000048/
# No Full Cast & Crew link found for https://www.imdb.com/title/tt1000048/
# Fetching cast and crew for movie ID tt1000049 from https://www.imdb.com/title/tt1000049/
# Fetching cast and crew for movie ID tt1000050 from https://www.imdb.com/title/tt1000050/
# Fetching cast and crew for movie ID tt1000051 from https://www.imdb.com/title/tt1000051/
# Fetching cast and crew for movie ID tt1000052 from https://www.imdb.com/title/tt1000052/
# Fetching cast and crew for movie ID tt1000053 from https://www.imdb.com/title/tt1000053/
# Fetching cast and crew for movie ID tt1000054 from https://www.imdb.com/title/tt1000054/
# Fetching cast and crew for movie ID tt1000055 from https://www.imdb.com/title/tt1000055/
# Fetching cast and crew for movie ID tt1000056 from https://www.imdb.com/title/tt1000056/
# Fetching cast and crew for movie ID tt1000057 from https://www.imdb.com/title/tt1000057/
# Fetching cast and crew for movie ID tt1000058 from https://www.imdb.com/title/tt1000058/
# Fetching cast and crew for movie ID tt1000059 from https://www.imdb.com/title/tt1000059/
# Fetching cast and crew for movie ID tt1000060 from https://www.imdb.com/title/tt1000060/
# Fetching cast and crew for movie ID tt1000061 from https://www.imdb.com/title/tt1000061/
# Fetching cast and crew for movie ID tt1000062 from https://www.imdb.com/title/tt1000062/
# Fetching cast and crew for movie ID tt1000063 from https://www.imdb.com/title/tt1000063/
# Fetching cast and crew for movie ID tt1000064 from https://www.imdb.com/title/tt1000064/
# Fetching cast and crew for movie ID tt1000065 from https://www.imdb.com/title/tt1000065/
# Fetching cast and crew for movie ID tt1000066 from https://www.imdb.com/title/tt1000066/
# Fetching cast and crew for movie ID tt1000067 from https://www.imdb.com/title/tt1000067/
# Fetching cast and crew for movie ID tt1000068 from https://www.imdb.com/title/tt1000068/
# Fetching cast and crew for movie ID tt1000069 from https://www.imdb.com/title/tt1000069/
# Fetching cast and crew for movie ID tt1000070 from https://www.imdb.com/title/tt1000070/
# Fetching cast and crew for movie ID tt1000071 from https://www.imdb.com/title/tt1000071/
# Fetching cast and crew for movie ID tt1000072 from https://www.imdb.com/title/tt1000072/
# Fetching cast and crew for movie ID tt1000073 from https://www.imdb.com/title/tt1000073/
# Fetching cast and crew for movie ID tt1000074 from https://www.imdb.com/title/tt1000074/
# Fetching cast and crew for movie ID tt1000075 from https://www.imdb.com/title/tt1000075/
# Fetching cast and crew for movie ID tt1000076 from https://www.imdb.com/title/tt1000076/
# Fetching cast and crew for movie ID tt1000077 from https://www.imdb.com/title/tt1000077/
# Fetching cast and crew for movie ID tt1000078 from https://www.imdb.com/title/tt1000078/
# Fetching cast and crew for movie ID tt1000079 from https://www.imdb.com/title/tt1000079/
# Fetching cast and crew for movie ID tt1000080 from https://www.imdb.com/title/tt1000080/
# Fetching cast and crew for movie ID tt1000081 from https://www.imdb.com/title/tt1000081/
# Fetching cast and crew for movie ID tt1000082 from https://www.imdb.com/title/tt1000082/
# Fetching cast and crew for movie ID tt1000083 from https://www.imdb.com/title/tt1000083/
# Fetching cast and crew for movie ID tt1000084 from https://www.imdb.com/title/tt1000084/
# Fetching cast and crew for movie ID tt1000085 from https://www.imdb.com/title/tt1000085/
# Fetching cast and crew for movie ID tt1000086 from https://www.imdb.com/title/tt1000086/
# Fetching cast and crew for movie ID tt1000087 from https://www.imdb.com/title/tt1000087/
# Fetching cast and crew for movie ID tt1000088 from https://www.imdb.com/title/tt1000088/
# Fetching cast and crew for movie ID tt1000089 from https://www.imdb.com/title/tt1000089/
# Fetching cast and crew for movie ID tt1000090 from https://www.imdb.com/title/tt1000090/
# Fetching cast and crew for movie ID tt1000091 from https://www.imdb.com/title/tt1000091/
# Fetching cast and crew for movie ID tt1000092 from https://www.imdb.com/title/tt1000092/
# Fetching cast and crew for movie ID tt1000093 from https://www.imdb.com/title/tt1000093/
# Fetching cast and crew for movie ID tt1000094 from https://www.imdb.com/title/tt1000094/
# Fetching cast and crew for movie ID tt1000095 from https://www.imdb.com/title/tt1000095/
# Fetching cast and crew for movie ID tt1000096 from https://www.imdb.com/title/tt1000096/
# Fetching cast and crew for movie ID tt1000097 from https://www.imdb.com/title/tt1000097/
# Fetching cast and crew for movie ID tt1000098 from https://www.imdb.com/title/tt1000098/
# Fetching cast and crew for movie ID tt1000099 from https://www.imdb.com/title/tt1000099/
# Fetching cast and crew for movie ID tt1000100 from https://www.imdb.com/title/tt1000100/
# Fetching cast and crew for movie ID tt1000101 from https://www.imdb.com/title/tt1000101/
# Fetching cast and crew for movie ID tt1000102 from https://www.imdb.com/title/tt1000102/
# Fetching cast and crew for movie ID tt1000103 from https://www.imdb.com/title/tt1000103/
# Fetching cast and crew for movie ID tt1000104 from https://www.imdb.com/title/tt1000104/
# Fetching cast and crew for movie ID tt1000105 from https://www.imdb.com/title/tt1000105/
# Fetching cast and crew for movie ID tt1000106 from https://www.imdb.com/title/tt1000106/
# Fetching cast and crew for movie ID tt1000107 from https://www.imdb.com/title/tt1000107/
# Fetching cast and crew for movie ID tt1000108 from https://www.imdb.com/title/tt1000108/
# Fetching cast and crew for movie ID tt1000109 from https://www.imdb.com/title/tt1000109/
# Fetching cast and crew for movie ID tt1000110 from https://www.imdb.com/title/tt1000110/
# Fetching cast and crew for movie ID tt1000111 from https://www.imdb.com/title/tt1000111/
# Fetching cast and crew for movie ID tt1000112 from https://www.imdb.com/title/tt1000112/
# Fetching cast and crew for movie ID tt1000113 from https://www.imdb.com/title/tt1000113/
# Fetching cast and crew for movie ID tt1000114 from https://www.imdb.com/title/tt1000114/
# Fetching cast and crew for movie ID tt1000115 from https://www.imdb.com/title/tt1000115/
# Fetching cast and crew for movie ID tt1000116 from https://www.imdb.com/title/tt1000116/
# Fetching cast and crew for movie ID tt1000117 from https://www.imdb.com/title/tt1000117/
# Fetching cast and crew for movie ID tt1000118 from https://www.imdb.com/title/tt1000118/
# Fetching cast and crew for movie ID tt1000119 from https://www.imdb.com/title/tt1000119/
# Fetching cast and crew for movie ID tt1000120 from https://www.imdb.com/title/tt1000120/
# Fetching cast and crew for movie ID tt1000121 from https://www.imdb.com/title/tt1000121/
# Fetching cast and crew for movie ID tt1000122 from https://www.imdb.com/title/tt1000122/
# Fetching cast and crew for movie ID tt1000123 from https://www.imdb.com/title/tt1000123/
# Fetching cast and crew for movie ID tt1000124 from https://www.imdb.com/title/tt1000124/
# Fetching cast and crew for movie ID tt1000125 from https://www.imdb.com/title/tt1000125/
# Fetching cast and crew for movie ID tt1000126 from https://www.imdb.com/title/tt1000126/
# Fetching cast and crew for movie ID tt1000127 from https://www.imdb.com/title/tt1000127/
# Fetching cast and crew for movie ID tt1000128 from https://www.imdb.com/title/tt1000128/
# Fetching cast and crew for movie ID tt1000129 from https://www.imdb.com/title/tt1000129/
# Fetching cast and crew for movie ID tt1000130 from https://www.imdb.com/title/tt1000130/
# Fetching cast and crew for movie ID tt1000131 from https://www.imdb.com/title/tt1000131/
# Fetching cast and crew for movie ID tt1000132 from https://www.imdb.com/title/tt1000132/
# Fetching cast and crew for movie ID tt1000133 from https://www.imdb.com/title/tt1000133/
# Fetching cast and crew for movie ID tt1000134 from https://www.imdb.com/title/tt1000134/
# Fetching cast and crew for movie ID tt1000135 from https://www.imdb.com/title/tt1000135/
# Fetching cast and crew for movie ID tt1000136 from https://www.imdb.com/title/tt1000136/
# Fetching cast and crew for movie ID tt1000137 from https://www.imdb.com/title/tt1000137/
# Fetching cast and crew for movie ID tt1000138 from https://www.imdb.com/title/tt1000138/
# Fetching cast and crew for movie ID tt1000139 from https://www.imdb.com/title/tt1000139/
# Fetching cast and crew for movie ID tt1000140 from https://www.imdb.com/title/tt1000140/
# Fetching cast and crew for movie ID tt1000141 from https://www.imdb.com/title/tt1000141/
# Fetching cast and crew for movie ID tt1000142 from https://www.imdb.com/title/tt1000142/
# Fetching cast and crew for movie ID tt1000143 from https://www.imdb.com/title/tt1000143/
# Fetching cast and crew for movie ID tt1000144 from https://www.imdb.com/title/tt1000144/
# Fetching cast and crew for movie ID tt1000145 from https://www.imdb.com/title/tt1000145/
# Fetching cast and crew for movie ID tt1000146 from https://www.imdb.com/title/tt1000146/
# Fetching cast and crew for movie ID tt1000147 from https://www.imdb.com/title/tt1000147/
# Fetching cast and crew for movie ID tt1000148 from https://www.imdb.com/title/tt1000148/
# Fetching cast and crew for movie ID tt1000149 from https://www.imdb.com/title/tt1000149/
# Fetching cast and crew for movie ID tt1000150 from https://www.imdb.com/title/tt1000150/
# Fetching cast and crew for movie ID tt1000151 from https://www.imdb.com/title/tt1000151/
# Fetching cast and crew for movie ID tt1000152 from https://www.imdb.com/title/tt1000152/
# Fetching cast and crew for movie ID tt1000153 from https://www.imdb.com/title/tt1000153/
# No Full Cast & Crew link found for https://www.imdb.com/title/tt1000153/
# Fetching cast and crew for movie ID tt1000154 from https://www.imdb.com/title/tt1000154/
# Fetching cast and crew for movie ID tt1000155 from https://www.imdb.com/title/tt1000155/
# Fetching cast and crew for movie ID tt1000156 from https://www.imdb.com/title/tt1000156/
# Fetching cast and crew for movie ID tt1000157 from https://www.imdb.com/title/tt1000157/
# No Full Cast & Crew link found for https://www.imdb.com/title/tt1000157/
# Fetching cast and crew for movie ID tt1000158 from https://www.imdb.com/title/tt1000158/
# Fetching cast and crew for movie ID tt1000159 from https://www.imdb.com/title/tt1000159/
# No Full Cast & Crew link found for https://www.imdb.com/title/tt1000159/
# Fetching cast and crew for movie ID tt1000160 from https://www.imdb.com/title/tt1000160/
# Fetching cast and crew for movie ID tt1000161 from https://www.imdb.com/title/tt1000161/
# Fetching cast and crew for movie ID tt1000162 from https://www.imdb.com/title/tt1000162/
# Fetching cast and crew for movie ID tt1000163 from https://www.imdb.com/title/tt1000163/
# Fetching cast and crew for movie ID tt1000164 from https://www.imdb.com/title/tt1000164/
# Fetching cast and crew for movie ID tt1000165 from https://www.imdb.com/title/tt1000165/
# Fetching cast and crew for movie ID tt1000166 from https://www.imdb.com/title/tt1000166/
# Fetching cast and crew for movie ID tt1000167 from https://www.imdb.com/title/tt1000167/
# Fetching cast and crew for movie ID tt1000168 from https://www.imdb.com/title/tt1000168/
# Fetching cast and crew for movie ID tt1000169 from https://www.imdb.com/title/tt1000169/
# Fetching cast and crew for movie ID tt1000170 from https://www.imdb.com/title/tt1000170/
# Fetching cast and crew for movie ID tt1000171 from https://www.imdb.com/title/tt1000171/
# Fetching cast and crew for movie ID tt1000172 from https://www.imdb.com/title/tt1000172/
# Fetching cast and crew for movie ID tt1000173 from https://www.imdb.com/title/tt1000173/
# Fetching cast and crew for movie ID tt1000174 from https://www.imdb.com/title/tt1000174/
# Fetching cast and crew for movie ID tt1000175 from https://www.imdb.com/title/tt1000175/
# Fetching cast and crew for movie ID tt1000176 from https://www.imdb.com/title/tt1000176/
# Fetching cast and crew for movie ID tt1000177 from https://www.imdb.com/title/tt1000177/
# Fetching cast and crew for movie ID tt1000178 from https://www.imdb.com/title/tt1000178/
# Fetching cast and crew for movie ID tt1000179 from https://www.imdb.com/title/tt1000179/
# Fetching cast and crew for movie ID tt1000180 from https://www.imdb.com/title/tt1000180/
# Fetching cast and crew for movie ID tt1000181 from https://www.imdb.com/title/tt1000181/
# Fetching cast and crew for movie ID tt1000182 from https://www.imdb.com/title/tt1000182/
# Fetching cast and crew for movie ID tt1000183 from https://www.imdb.com/title/tt1000183/
# Fetching cast and crew for movie ID tt1000184 from https://www.imdb.com/title/tt1000184/
# Fetching cast and crew for movie ID tt1000185 from https://www.imdb.com/title/tt1000185/
# Fetching cast and crew for movie ID tt1000186 from https://www.imdb.com/title/tt1000186/
# Fetching cast and crew for movie ID tt1000187 from https://www.imdb.com/title/tt1000187/
# Fetching cast and crew for movie ID tt1000188 from https://www.imdb.com/title/tt1000188/
# Fetching cast and crew for movie ID tt1000189 from https://www.imdb.com/title/tt1000189/
# Fetching cast and crew for movie ID tt1000190 from https://www.imdb.com/title/tt1000190/
# Fetching cast and crew for movie ID tt1000191 from https://www.imdb.com/title/tt1000191/
# Fetching cast and crew for movie ID tt1000192 from https://www.imdb.com/title/tt1000192/
# Fetching cast and crew for movie ID tt1000193 from https://www.imdb.com/title/tt1000193/
# Fetching cast and crew for movie ID tt1000194 from https://www.imdb.com/title/tt1000194/
# Fetching cast and crew for movie ID tt1000195 from https://www.imdb.com/title/tt1000195/
# Fetching cast and crew for movie ID tt1000196 from https://www.imdb.com/title/tt1000196/
# Fetching cast and crew for movie ID tt1000197 from https://www.imdb.com/title/tt1000197/
# Fetching cast and crew for movie ID tt1000198 from https://www.imdb.com/title/tt1000198/
# Fetching cast and crew for movie ID tt1000199 from https://www.imdb.com/title/tt1000199/
# Fetching cast and crew for movie ID tt1000200 from https://www.imdb.com/title/tt1000200/
# Fetching cast and crew for movie ID tt1000201 from https://www.imdb.com/title/tt1000201/
# Fetching cast and crew for movie ID tt1000202 from https://www.imdb.com/title/tt1000202/
# Fetching cast and crew for movie ID tt1000203 from https://www.imdb.com/title/tt1000203/
# Fetching cast and crew for movie ID tt1000204 from https://www.imdb.com/title/tt1000204/
# Fetching cast and crew for movie ID tt1000205 from https://www.imdb.com/title/tt1000205/
# Fetching cast and crew for movie ID tt1000206 from https://www.imdb.com/title/tt1000206/
# Fetching cast and crew for movie ID tt1000207 from https://www.imdb.com/title/tt1000207/
# Fetching cast and crew for movie ID tt1000208 from https://www.imdb.com/title/tt1000208/
# Fetching cast and crew for movie ID tt1000209 from https://www.imdb.com/title/tt1000209/
# Fetching cast and crew for movie ID tt1000210 from https://www.imdb.com/title/tt1000210/
# Fetching cast and crew for movie ID tt1000211 from https://www.imdb.com/title/tt1000211/
# Fetching cast and crew for movie ID tt1000212 from https://www.imdb.com/title/tt1000212/
# Fetching cast and crew for movie ID tt1000213 from https://www.imdb.com/title/tt1000213/
# Fetching cast and crew for movie ID tt1000214 from https://www.imdb.com/title/tt1000214/
# Fetching cast and crew for movie ID tt1000215 from https://www.imdb.com/title/tt1000215/
# Fetching cast and crew for movie ID tt1000216 from https://www.imdb.com/title/tt1000216/
# Fetching cast and crew for movie ID tt1000217 from https://www.imdb.com/title/tt1000217/
# Fetching cast and crew for movie ID tt1000218 from https://www.imdb.com/title/tt1000218/
# Fetching cast and crew for movie ID tt1000219 from https://www.imdb.com/title/tt1000219/
# Fetching cast and crew for movie ID tt1000220 from https://www.imdb.com/title/tt1000220/
# Fetching cast and crew for movie ID tt1000221 from https://www.imdb.com/title/tt1000221/
# Fetching cast and crew for movie ID tt1000222 from https://www.imdb.com/title/tt1000222/
# Fetching cast and crew for movie ID tt1000223 from https://www.imdb.com/title/tt1000223/
# Fetching cast and crew for movie ID tt1000224 from https://www.imdb.com/title/tt1000224/
# Fetching cast and crew for movie ID tt1000225 from https://www.imdb.com/title/tt1000225/
# Fetching cast and crew for movie ID tt1000226 from https://www.imdb.com/title/tt1000226/
# Fetching cast and crew for movie ID tt1000227 from https://www.imdb.com/title/tt1000227/
# Fetching cast and crew for movie ID tt1000228 from https://www.imdb.com/title/tt1000228/
# Fetching cast and crew for movie ID tt1000229 from https://www.imdb.com/title/tt1000229/
# Fetching cast and crew for movie ID tt1000230 from https://www.imdb.com/title/tt1000230/
# Fetching cast and crew for movie ID tt1000231 from https://www.imdb.com/title/tt1000231/
# Fetching cast and crew for movie ID tt1000232 from https://www.imdb.com/title/tt1000232/
# Fetching cast and crew for movie ID tt1000233 from https://www.imdb.com/title/tt1000233/
# Fetching cast and crew for movie ID tt1000234 from https://www.imdb.com/title/tt1000234/
# Fetching cast and crew for movie ID tt1000235 from https://www.imdb.com/title/tt1000235/
# Fetching cast and crew for movie ID tt1000236 from https://www.imdb.com/title/tt1000236/
# Fetching cast and crew for movie ID tt1000237 from https://www.imdb.com/title/tt1000237/
# Fetching cast and crew for movie ID tt1000238 from https://www.imdb.com/title/tt1000238/
# Fetching cast and crew for movie ID tt1000239 from https://www.imdb.com/title/tt1000239/
# Fetching cast and crew for movie ID tt1000240 from https://www.imdb.com/title/tt1000240/
# Fetching cast and crew for movie ID tt1000241 from https://www.imdb.com/title/tt1000241/
# Fetching cast and crew for movie ID tt1000242 from https://www.imdb.com/title/tt1000242/
# Fetching cast and crew for movie ID tt1000243 from https://www.imdb.com/title/tt1000243/
# Fetching cast and crew for movie ID tt1000244 from https://www.imdb.com/title/tt1000244/
# Fetching cast and crew for movie ID tt1000245 from https://www.imdb.com/title/tt1000245/
# Fetching cast and crew for movie ID tt1000246 from https://www.imdb.com/title/tt1000246/
# Fetching cast and crew for movie ID tt1000247 from https://www.imdb.com/title/tt1000247/
# Fetching cast and crew for movie ID tt1000248 from https://www.imdb.com/title/tt1000248/
# Fetching cast and crew for movie ID tt1000249 from https://www.imdb.com/title/tt1000249/
# Fetching cast and crew for movie ID tt1000250 from https://www.imdb.com/title/tt1000250/
#     Movie_ID                    Name Role Type Character/Position
# 0  tt1000001             Julien Ball     Actor     Henry Thornton
# 1  tt1000001  Stephen Campbell Moore     Actor      John Clarkson
# 2  tt1000001         Niall Macgregor     Actor     Charles Taylor
# 3  tt1000001          Joseph Marcell     Actor       David George
# 4  tt1000001         Alice O'Connell     Actor       Susannah Lee

# %%
import requests
from bs4 import BeautifulSoup
import json
import time
import pandas as pd

headers = {
    'Accept': '/',
    'Connection': 'keep-alive',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.0) AppleWebKit/537.36 (KHTML,like Gecko) Chrome/70.0.3538.110 Safari/537.36',
    'Accept-Language': 'en-US;q=0.5,en;q=0.3',
    'Cache-Control': 'max-age=0',
    'Upgrade-Insecure-Requests': '1'
}

response = requests.get('https://www.imdb.com/chart/top/', headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')


data = json.loads(soup.find('script', {'type': "application/ld+json"}).text)
movie_urls = [item['item']['url'] for item in data['itemListElement'][:250]]

print(f"Found {len(movie_urls)} movie URLs.")


def fetch_cast_and_crew(movie_url, movie_id):
    cast_and_crew = []
    try:
        response = requests.get(movie_url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')

        full_cast_link = None
        for link in soup.find_all("a", href=True):
            if "fullcredits" in link['href']:
                full_cast_link = "https://www.imdb.com" + link['href']
                break

        if full_cast_link:
            cast_response = requests.get(full_cast_link, headers=headers)
            cast_soup = BeautifulSoup(cast_response.content, 'html.parser')

            cast_table = cast_soup.find("table", class_="cast_list")
            if cast_table:
                for row in cast_table.find_all("tr")[1:]:
                    cols = row.find_all("td")
                    if len(cols) >= 2:
                        name = cols[1].text.strip()
                        character = cols[3].text.strip() if len(cols) > 3 else "N/A"
                        cast_and_crew.append({
                            "Movie_ID": movie_id,
                            "Name": name,
                            "Role Type": "Actor",
                            "Character/Position": character
                        })

            
            produced_by_section = cast_soup.find("h4", string="Produced by")
            if produced_by_section:
                for producer in produced_by_section.find_next("ul").find_all("li"):
                    name = producer.text.strip()
                    cast_and_crew.append({
                        "Movie_ID": movie_id,
                        "Name": name,
                        "Role Type": "Producer",
                        "Character/Position": "N/A"
                    })
        else:
            print(f"No Full Cast & Crew link found for {movie_url}")

    except Exception as e:
        print(f"Error scraping cast & crew for {movie_url}: {e}")

    return cast_and_crew


full_cast_and_crew_list = []


for movie_url in movie_urls:
    movie_id = movie_url.split("/")[4] 
    print(f"Fetching cast and crew for movie ID {movie_id} from {movie_url}")

    cast_and_crew = fetch_cast_and_crew(movie_url, movie_id)
    full_cast_and_crew_list.extend(cast_and_crew)

    time.sleep(1)  


full_cast_and_crew_df = pd.DataFrame(full_cast_and_crew_list)


print(full_cast_and_crew_df.head())


full_cast_and_crew_df.to_csv("full_cast_and_crew.csv", index=False)

print("Full cast and crew data saved to 'full_cast_and_crew.csv'")
# Out:
# Found 250 movie URLs.
# Fetching cast and crew for movie ID tt0111161 from https://www.imdb.com/title/tt0111161/
# Fetching cast and crew for movie ID tt0068646 from https://www.imdb.com/title/tt0068646/
# Fetching cast and crew for movie ID tt0468569 from https://www.imdb.com/title/tt0468569/
# Fetching cast and crew for movie ID tt0071562 from https://www.imdb.com/title/tt0071562/
# Fetching cast and crew for movie ID tt0050083 from https://www.imdb.com/title/tt0050083/
# Fetching cast and crew for movie ID tt0167260 from https://www.imdb.com/title/tt0167260/
# Fetching cast and crew for movie ID tt0108052 from https://www.imdb.com/title/tt0108052/
# Fetching cast and crew for movie ID tt0110912 from https://www.imdb.com/title/tt0110912/
# Fetching cast and crew for movie ID tt0120737 from https://www.imdb.com/title/tt0120737/
# Fetching cast and crew for movie ID tt0060196 from https://www.imdb.com/title/tt0060196/
# Fetching cast and crew for movie ID tt0109830 from https://www.imdb.com/title/tt0109830/
# Fetching cast and crew for movie ID tt0167261 from https://www.imdb.com/title/tt0167261/
# Fetching cast and crew for movie ID tt0137523 from https://www.imdb.com/title/tt0137523/
# Fetching cast and crew for movie ID tt1375666 from https://www.imdb.com/title/tt1375666/
# Fetching cast and crew for movie ID tt0080684 from https://www.imdb.com/title/tt0080684/
# Fetching cast and crew for movie ID tt0133093 from https://www.imdb.com/title/tt0133093/
# Fetching cast and crew for movie ID tt0099685 from https://www.imdb.com/title/tt0099685/
# Fetching cast and crew for movie ID tt0073486 from https://www.imdb.com/title/tt0073486/
# Fetching cast and crew for movie ID tt0816692 from https://www.imdb.com/title/tt0816692/
# Fetching cast and crew for movie ID tt0114369 from https://www.imdb.com/title/tt0114369/
# Fetching cast and crew for movie ID tt0038650 from https://www.imdb.com/title/tt0038650/
# Fetching cast and crew for movie ID tt0047478 from https://www.imdb.com/title/tt0047478/
# Fetching cast and crew for movie ID tt0102926 from https://www.imdb.com/title/tt0102926/
# Fetching cast and crew for movie ID tt0120815 from https://www.imdb.com/title/tt0120815/
# Fetching cast and crew for movie ID tt0317248 from https://www.imdb.com/title/tt0317248/
# Fetching cast and crew for movie ID tt0120689 from https://www.imdb.com/title/tt0120689/
# Fetching cast and crew for movie ID tt0118799 from https://www.imdb.com/title/tt0118799/
# Fetching cast and crew for movie ID tt0103064 from https://www.imdb.com/title/tt0103064/
# Fetching cast and crew for movie ID tt0076759 from https://www.imdb.com/title/tt0076759/
# Fetching cast and crew for movie ID tt0088763 from https://www.imdb.com/title/tt0088763/
# Fetching cast and crew for movie ID tt0245429 from https://www.imdb.com/title/tt0245429/
# Fetching cast and crew for movie ID tt0253474 from https://www.imdb.com/title/tt0253474/
# Fetching cast and crew for movie ID tt6751668 from https://www.imdb.com/title/tt6751668/
# Fetching cast and crew for movie ID tt0172495 from https://www.imdb.com/title/tt0172495/
# Fetching cast and crew for movie ID tt0054215 from https://www.imdb.com/title/tt0054215/
# Fetching cast and crew for movie ID tt0110357 from https://www.imdb.com/title/tt0110357/
# Fetching cast and crew for movie ID tt0407887 from https://www.imdb.com/title/tt0407887/
# Fetching cast and crew for movie ID tt0095327 from https://www.imdb.com/title/tt0095327/
# Fetching cast and crew for movie ID tt9362722 from https://www.imdb.com/title/tt9362722/
# Fetching cast and crew for movie ID tt2582802 from https://www.imdb.com/title/tt2582802/
# Fetching cast and crew for movie ID tt0120586 from https://www.imdb.com/title/tt0120586/
# Fetching cast and crew for movie ID tt0482571 from https://www.imdb.com/title/tt0482571/
# Fetching cast and crew for movie ID tt0110413 from https://www.imdb.com/title/tt0110413/
# Fetching cast and crew for movie ID tt0056058 from https://www.imdb.com/title/tt0056058/
# Fetching cast and crew for movie ID tt0034583 from https://www.imdb.com/title/tt0034583/
# Fetching cast and crew for movie ID tt0114814 from https://www.imdb.com/title/tt0114814/
# Fetching cast and crew for movie ID tt1675434 from https://www.imdb.com/title/tt1675434/
# Fetching cast and crew for movie ID tt0095765 from https://www.imdb.com/title/tt0095765/
# Fetching cast and crew for movie ID tt15239678 from https://www.imdb.com/title/tt15239678/
# Fetching cast and crew for movie ID tt0027977 from https://www.imdb.com/title/tt0027977/
# Fetching cast and crew for movie ID tt0078748 from https://www.imdb.com/title/tt0078748/
# Fetching cast and crew for movie ID tt0047396 from https://www.imdb.com/title/tt0047396/
# Fetching cast and crew for movie ID tt0064116 from https://www.imdb.com/title/tt0064116/
# Fetching cast and crew for movie ID tt1853728 from https://www.imdb.com/title/tt1853728/
# Fetching cast and crew for movie ID tt0021749 from https://www.imdb.com/title/tt0021749/
# Fetching cast and crew for movie ID tt0078788 from https://www.imdb.com/title/tt0078788/
# Fetching cast and crew for movie ID tt0209144 from https://www.imdb.com/title/tt0209144/
# Fetching cast and crew for movie ID tt0910970 from https://www.imdb.com/title/tt0910970/
# Fetching cast and crew for movie ID tt0082971 from https://www.imdb.com/title/tt0082971/
# Fetching cast and crew for movie ID tt0405094 from https://www.imdb.com/title/tt0405094/
# Fetching cast and crew for movie ID tt23849204 from https://www.imdb.com/title/tt23849204/
# Fetching cast and crew for movie ID tt4154756 from https://www.imdb.com/title/tt4154756/
# Fetching cast and crew for movie ID tt0043014 from https://www.imdb.com/title/tt0043014/
# Fetching cast and crew for movie ID tt4633694 from https://www.imdb.com/title/tt4633694/
# Fetching cast and crew for movie ID tt0050825 from https://www.imdb.com/title/tt0050825/
# Fetching cast and crew for movie ID tt0051201 from https://www.imdb.com/title/tt0051201/
# Fetching cast and crew for movie ID tt0081505 from https://www.imdb.com/title/tt0081505/
# Fetching cast and crew for movie ID tt0032553 from https://www.imdb.com/title/tt0032553/
# Fetching cast and crew for movie ID tt0090605 from https://www.imdb.com/title/tt0090605/
# Fetching cast and crew for movie ID tt0361748 from https://www.imdb.com/title/tt0361748/
# Fetching cast and crew for movie ID tt1345836 from https://www.imdb.com/title/tt1345836/
# Fetching cast and crew for movie ID tt2380307 from https://www.imdb.com/title/tt2380307/
# Fetching cast and crew for movie ID tt0086879 from https://www.imdb.com/title/tt0086879/
# Fetching cast and crew for movie ID tt0114709 from https://www.imdb.com/title/tt0114709/
# Fetching cast and crew for movie ID tt0057012 from https://www.imdb.com/title/tt0057012/
# Fetching cast and crew for movie ID tt0364569 from https://www.imdb.com/title/tt0364569/
# Fetching cast and crew for movie ID tt0169547 from https://www.imdb.com/title/tt0169547/
# Fetching cast and crew for movie ID tt4154796 from https://www.imdb.com/title/tt4154796/
# Fetching cast and crew for movie ID tt0119217 from https://www.imdb.com/title/tt0119217/
# Fetching cast and crew for movie ID tt0082096 from https://www.imdb.com/title/tt0082096/
# Fetching cast and crew for movie ID tt0112573 from https://www.imdb.com/title/tt0112573/
# Fetching cast and crew for movie ID tt0119698 from https://www.imdb.com/title/tt0119698/
# Fetching cast and crew for movie ID tt5311514 from https://www.imdb.com/title/tt5311514/
# Fetching cast and crew for movie ID tt0057565 from https://www.imdb.com/title/tt0057565/
# Fetching cast and crew for movie ID tt7286456 from https://www.imdb.com/title/tt7286456/
# Fetching cast and crew for movie ID tt1187043 from https://www.imdb.com/title/tt1187043/
# Fetching cast and crew for movie ID tt0087843 from https://www.imdb.com/title/tt0087843/
# Fetching cast and crew for movie ID tt0045152 from https://www.imdb.com/title/tt0045152/
# Fetching cast and crew for movie ID tt8267604 from https://www.imdb.com/title/tt8267604/
# Fetching cast and crew for movie ID tt0091251 from https://www.imdb.com/title/tt0091251/
# Fetching cast and crew for movie ID tt0180093 from https://www.imdb.com/title/tt0180093/
# Fetching cast and crew for movie ID tt0435761 from https://www.imdb.com/title/tt0435761/
# Fetching cast and crew for movie ID tt0086190 from https://www.imdb.com/title/tt0086190/
# Fetching cast and crew for movie ID tt2106476 from https://www.imdb.com/title/tt2106476/
# Fetching cast and crew for movie ID tt0338013 from https://www.imdb.com/title/tt0338013/
# Fetching cast and crew for movie ID tt0044741 from https://www.imdb.com/title/tt0044741/
# Fetching cast and crew for movie ID tt0062622 from https://www.imdb.com/title/tt0062622/
# Fetching cast and crew for movie ID tt0105236 from https://www.imdb.com/title/tt0105236/
# Fetching cast and crew for movie ID tt0056172 from https://www.imdb.com/title/tt0056172/
# Fetching cast and crew for movie ID tt0053604 from https://www.imdb.com/title/tt0053604/
# Fetching cast and crew for movie ID tt1255953 from https://www.imdb.com/title/tt1255953/
# Fetching cast and crew for movie ID tt0086250 from https://www.imdb.com/title/tt0086250/
# Fetching cast and crew for movie ID tt0053125 from https://www.imdb.com/title/tt0053125/
# Fetching cast and crew for movie ID tt0036775 from https://www.imdb.com/title/tt0036775/
# Fetching cast and crew for movie ID tt0033467 from https://www.imdb.com/title/tt0033467/
# Fetching cast and crew for movie ID tt0022100 from https://www.imdb.com/title/tt0022100/
# Fetching cast and crew for movie ID tt0113277 from https://www.imdb.com/title/tt0113277/
# Fetching cast and crew for movie ID tt0052357 from https://www.imdb.com/title/tt0052357/
# Fetching cast and crew for movie ID tt0093058 from https://www.imdb.com/title/tt0093058/
# Fetching cast and crew for movie ID tt15398776 from https://www.imdb.com/title/tt15398776/
# Fetching cast and crew for movie ID tt1049413 from https://www.imdb.com/title/tt1049413/
# Fetching cast and crew for movie ID tt0211915 from https://www.imdb.com/title/tt0211915/
# Fetching cast and crew for movie ID tt0066921 from https://www.imdb.com/title/tt0066921/
# Fetching cast and crew for movie ID tt0056592 from https://www.imdb.com/title/tt0056592/
# Fetching cast and crew for movie ID tt1832382 from https://www.imdb.com/title/tt1832382/
# Fetching cast and crew for movie ID tt0070735 from https://www.imdb.com/title/tt0070735/
# Fetching cast and crew for movie ID tt0095016 from https://www.imdb.com/title/tt0095016/
# Fetching cast and crew for movie ID tt0097576 from https://www.imdb.com/title/tt0097576/
# Fetching cast and crew for movie ID tt0986264 from https://www.imdb.com/title/tt0986264/
# Fetching cast and crew for movie ID tt0017136 from https://www.imdb.com/title/tt0017136/
# Fetching cast and crew for movie ID tt0208092 from https://www.imdb.com/title/tt0208092/
# Fetching cast and crew for movie ID tt8579674 from https://www.imdb.com/title/tt8579674/
# Fetching cast and crew for movie ID tt0119488 from https://www.imdb.com/title/tt0119488/
# Fetching cast and crew for movie ID tt0040522 from https://www.imdb.com/title/tt0040522/
# Fetching cast and crew for movie ID tt0363163 from https://www.imdb.com/title/tt0363163/
# Fetching cast and crew for movie ID tt0075314 from https://www.imdb.com/title/tt0075314/
# Fetching cast and crew for movie ID tt8503618 from https://www.imdb.com/title/tt8503618/
# Fetching cast and crew for movie ID tt5074352 from https://www.imdb.com/title/tt5074352/
# Fetching cast and crew for movie ID tt0993846 from https://www.imdb.com/title/tt0993846/
# Fetching cast and crew for movie ID tt0372784 from https://www.imdb.com/title/tt0372784/
# Fetching cast and crew for movie ID tt0059578 from https://www.imdb.com/title/tt0059578/
# Fetching cast and crew for movie ID tt6966692 from https://www.imdb.com/title/tt6966692/
# Fetching cast and crew for movie ID tt0053291 from https://www.imdb.com/title/tt0053291/
# Fetching cast and crew for movie ID tt0120382 from https://www.imdb.com/title/tt0120382/
# Fetching cast and crew for movie ID tt0055031 from https://www.imdb.com/title/tt0055031/
# Fetching cast and crew for movie ID tt0012349 from https://www.imdb.com/title/tt0012349/
# Fetching cast and crew for movie ID tt10272386 from https://www.imdb.com/title/tt10272386/
# Fetching cast and crew for movie ID tt1130884 from https://www.imdb.com/title/tt1130884/
# Fetching cast and crew for movie ID tt0042192 from https://www.imdb.com/title/tt0042192/
# Fetching cast and crew for movie ID tt0469494 from https://www.imdb.com/title/tt0469494/
# Fetching cast and crew for movie ID tt0107290 from https://www.imdb.com/title/tt0107290/
# Fetching cast and crew for movie ID tt0112641 from https://www.imdb.com/title/tt0112641/
# Fetching cast and crew for movie ID tt1745960 from https://www.imdb.com/title/tt1745960/
# Fetching cast and crew for movie ID tt0167404 from https://www.imdb.com/title/tt0167404/
# Fetching cast and crew for movie ID tt0089881 from https://www.imdb.com/title/tt0089881/
# Fetching cast and crew for movie ID tt0457430 from https://www.imdb.com/title/tt0457430/
# Fetching cast and crew for movie ID tt0477348 from https://www.imdb.com/title/tt0477348/
# Fetching cast and crew for movie ID tt0105695 from https://www.imdb.com/title/tt0105695/
# Fetching cast and crew for movie ID tt0084787 from https://www.imdb.com/title/tt0084787/
# Fetching cast and crew for movie ID tt0268978 from https://www.imdb.com/title/tt0268978/
# Fetching cast and crew for movie ID tt0266697 from https://www.imdb.com/title/tt0266697/
# Fetching cast and crew for movie ID tt0040897 from https://www.imdb.com/title/tt0040897/
# Fetching cast and crew for movie ID tt0055630 from https://www.imdb.com/title/tt0055630/
# Fetching cast and crew for movie ID tt29623480 from https://www.imdb.com/title/tt29623480/
# Fetching cast and crew for movie ID tt1392214 from https://www.imdb.com/title/tt1392214/
# Fetching cast and crew for movie ID tt0266543 from https://www.imdb.com/title/tt0266543/
# Fetching cast and crew for movie ID tt0057115 from https://www.imdb.com/title/tt0057115/
# Fetching cast and crew for movie ID tt0071853 from https://www.imdb.com/title/tt0071853/
# Fetching cast and crew for movie ID tt0347149 from https://www.imdb.com/title/tt0347149/
# Fetching cast and crew for movie ID tt0080678 from https://www.imdb.com/title/tt0080678/
# Fetching cast and crew for movie ID tt0042876 from https://www.imdb.com/title/tt0042876/
# Fetching cast and crew for movie ID tt0046912 from https://www.imdb.com/title/tt0046912/
# Fetching cast and crew for movie ID tt0031381 from https://www.imdb.com/title/tt0031381/
# Fetching cast and crew for movie ID tt0071315 from https://www.imdb.com/title/tt0071315/
# Fetching cast and crew for movie ID tt1305806 from https://www.imdb.com/title/tt1305806/
# Fetching cast and crew for movie ID tt0120735 from https://www.imdb.com/title/tt0120735/
# Fetching cast and crew for movie ID tt2096673 from https://www.imdb.com/title/tt2096673/
# Fetching cast and crew for movie ID tt0434409 from https://www.imdb.com/title/tt0434409/
# Fetching cast and crew for movie ID tt16492678 from https://www.imdb.com/title/tt16492678/
# Fetching cast and crew for movie ID tt5027774 from https://www.imdb.com/title/tt5027774/
# Fetching cast and crew for movie ID tt0081398 from https://www.imdb.com/title/tt0081398/
# Fetching cast and crew for movie ID tt4729430 from https://www.imdb.com/title/tt4729430/
# Fetching cast and crew for movie ID tt0050212 from https://www.imdb.com/title/tt0050212/
# Fetching cast and crew for movie ID tt0117951 from https://www.imdb.com/title/tt0117951/
# Fetching cast and crew for movie ID tt0264464 from https://www.imdb.com/title/tt0264464/
# Fetching cast and crew for movie ID tt0116282 from https://www.imdb.com/title/tt0116282/
# Fetching cast and crew for movie ID tt1291584 from https://www.imdb.com/title/tt1291584/
# Fetching cast and crew for movie ID tt10872600 from https://www.imdb.com/title/tt10872600/
# Fetching cast and crew for movie ID tt1205489 from https://www.imdb.com/title/tt1205489/
# Fetching cast and crew for movie ID tt1201607 from https://www.imdb.com/title/tt1201607/
# Fetching cast and crew for movie ID tt0405159 from https://www.imdb.com/title/tt0405159/
# Fetching cast and crew for movie ID tt0096283 from https://www.imdb.com/title/tt0096283/
# Fetching cast and crew for movie ID tt1392190 from https://www.imdb.com/title/tt1392190/
# Fetching cast and crew for movie ID tt0052618 from https://www.imdb.com/title/tt0052618/
# Fetching cast and crew for movie ID tt0118849 from https://www.imdb.com/title/tt0118849/
# Fetching cast and crew for movie ID tt0072684 from https://www.imdb.com/title/tt0072684/
# Fetching cast and crew for movie ID tt2024544 from https://www.imdb.com/title/tt2024544/
# Fetching cast and crew for movie ID tt0083658 from https://www.imdb.com/title/tt0083658/
# Fetching cast and crew for movie ID tt0112471 from https://www.imdb.com/title/tt0112471/
# Fetching cast and crew for movie ID tt2278388 from https://www.imdb.com/title/tt2278388/
# Fetching cast and crew for movie ID tt2119532 from https://www.imdb.com/title/tt2119532/
# Fetching cast and crew for movie ID tt0097165 from https://www.imdb.com/title/tt0097165/
# Fetching cast and crew for movie ID tt2267998 from https://www.imdb.com/title/tt2267998/
# Fetching cast and crew for movie ID tt0353969 from https://www.imdb.com/title/tt0353969/
# Fetching cast and crew for movie ID tt26548265 from https://www.imdb.com/title/tt26548265/
# Fetching cast and crew for movie ID tt0107207 from https://www.imdb.com/title/tt0107207/
# Fetching cast and crew for movie ID tt0015864 from https://www.imdb.com/title/tt0015864/
# Fetching cast and crew for movie ID tt0198781 from https://www.imdb.com/title/tt0198781/
# Fetching cast and crew for movie ID tt3011894 from https://www.imdb.com/title/tt3011894/
# Fetching cast and crew for movie ID tt0382932 from https://www.imdb.com/title/tt0382932/
# Fetching cast and crew for movie ID tt0892769 from https://www.imdb.com/title/tt0892769/
# Fetching cast and crew for movie ID tt0077416 from https://www.imdb.com/title/tt0077416/
# Fetching cast and crew for movie ID tt0073195 from https://www.imdb.com/title/tt0073195/
# Fetching cast and crew for movie ID tt0017925 from https://www.imdb.com/title/tt0017925/
# Fetching cast and crew for movie ID tt0015324 from https://www.imdb.com/title/tt0015324/
# Fetching cast and crew for movie ID tt0978762 from https://www.imdb.com/title/tt0978762/
# Fetching cast and crew for movie ID tt0047296 from https://www.imdb.com/title/tt0047296/
# Fetching cast and crew for movie ID tt0046268 from https://www.imdb.com/title/tt0046268/
# Fetching cast and crew for movie ID tt1950186 from https://www.imdb.com/title/tt1950186/
# Fetching cast and crew for movie ID tt0031679 from https://www.imdb.com/title/tt0031679/
# Fetching cast and crew for movie ID tt0050986 from https://www.imdb.com/title/tt0050986/
# Fetching cast and crew for movie ID tt0041959 from https://www.imdb.com/title/tt0041959/
# Fetching cast and crew for movie ID tt3315342 from https://www.imdb.com/title/tt3315342/
# Fetching cast and crew for movie ID tt0075148 from https://www.imdb.com/title/tt0075148/
# Fetching cast and crew for movie ID tt0046438 from https://www.imdb.com/title/tt0046438/
# Fetching cast and crew for movie ID tt0118715 from https://www.imdb.com/title/tt0118715/
# Fetching cast and crew for movie ID tt0050976 from https://www.imdb.com/title/tt0050976/
# Fetching cast and crew for movie ID tt1895587 from https://www.imdb.com/title/tt1895587/
# Fetching cast and crew for movie ID tt3170832 from https://www.imdb.com/title/tt3170832/
# Fetching cast and crew for movie ID tt0088247 from https://www.imdb.com/title/tt0088247/
# Fetching cast and crew for movie ID tt0395169 from https://www.imdb.com/title/tt0395169/
# Fetching cast and crew for movie ID tt0091763 from https://www.imdb.com/title/tt0091763/
# Fetching cast and crew for movie ID tt0325980 from https://www.imdb.com/title/tt0325980/
# Fetching cast and crew for movie ID tt0113247 from https://www.imdb.com/title/tt0113247/
# Fetching cast and crew for movie ID tt0381681 from https://www.imdb.com/title/tt0381681/
# Fetching cast and crew for movie ID tt15097216 from https://www.imdb.com/title/tt15097216/
# Fetching cast and crew for movie ID tt0036868 from https://www.imdb.com/title/tt0036868/
# Fetching cast and crew for movie ID tt0019254 from https://www.imdb.com/title/tt0019254/
# Fetching cast and crew for movie ID tt0070047 from https://www.imdb.com/title/tt0070047/
# Fetching cast and crew for movie ID tt0032138 from https://www.imdb.com/title/tt0032138/
# Fetching cast and crew for movie ID tt0317705 from https://www.imdb.com/title/tt0317705/
# Fetching cast and crew for movie ID tt1979320 from https://www.imdb.com/title/tt1979320/
# Fetching cast and crew for movie ID tt0074958 from https://www.imdb.com/title/tt0074958/
# Fetching cast and crew for movie ID tt0092005 from https://www.imdb.com/title/tt0092005/
# Fetching cast and crew for movie ID tt1028532 from https://www.imdb.com/title/tt1028532/
# Fetching cast and crew for movie ID tt0059742 from https://www.imdb.com/title/tt0059742/
# Fetching cast and crew for movie ID tt0049902 from https://www.imdb.com/title/tt0049902/
# Fetching cast and crew for movie ID tt0476735 from https://www.imdb.com/title/tt0476735/
# Fetching cast and crew for movie ID tt4016934 from https://www.imdb.com/title/tt4016934/
# Fetching cast and crew for movie ID tt0035446 from https://www.imdb.com/title/tt0035446/
# Fetching cast and crew for movie ID tt0758758 from https://www.imdb.com/title/tt0758758/
# Fetching cast and crew for movie ID tt0058946 from https://www.imdb.com/title/tt0058946/
# Fetching cast and crew for movie ID tt0129167 from https://www.imdb.com/title/tt0129167/
# Fetching cast and crew for movie ID tt0032551 from https://www.imdb.com/title/tt0032551/
# Fetching cast and crew for movie ID tt0107048 from https://www.imdb.com/title/tt0107048/
# Fetching cast and crew for movie ID tt0245712 from https://www.imdb.com/title/tt0245712/
# Fetching cast and crew for movie ID tt0032976 from https://www.imdb.com/title/tt0032976/
# Fetching cast and crew for movie ID tt1454029 from https://www.imdb.com/title/tt1454029/
# Fetching cast and crew for movie ID tt0061512 from https://www.imdb.com/title/tt0061512/
# Fetching cast and crew for movie ID tt5323662 from https://www.imdb.com/title/tt5323662/
#     Movie_ID            Name Role Type        Character/Position
# 0  tt0111161     Tim Robbins     Actor             Andy Dufresne
# 1  tt0111161  Morgan Freeman     Actor  Ellis Boyd 'Red' Redding
# 2  tt0111161      Bob Gunton     Actor             Warden Norton
# 3  tt0111161  William Sadler     Actor                   Heywood
# 4  tt0111161    Clancy Brown     Actor            Captain Hadley
# Full cast and crew data saved to 'full_cast_and_crew.csv'

# %% [markdown]
# ## Extracting Top 250 Imbd Movies

# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
import time


headers = {
    'Accept': '/',
    'Connection': 'keep-alive',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.0) AppleWebKit/537.36 (KHTML,like Gecko) Chrome/70.0.3538.110 Safari/537.36',
    'Accept-Language': 'en-US;q=0.5,en;q=0.3',
    'Cache-Control': 'max-age=0',
    'Upgrade-Insecure-Requests': '1'
}

response = requests.get('https://www.imdb.com/chart/top/', headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')


data = json.loads(soup.find('script', {'type': "application/ld+json"}).text)


movie_urls = [item['item']['url'] for item in data['itemListElement'][:250]]

movies = []


for url in movie_urls:  # 
    movie_response = requests.get(url, headers=headers)
    movie_soup = BeautifulSoup(movie_response.content, 'html.parser')

    try:
       
        movie_id = url.split('/')[4]  

        
        title = movie_soup.find("h1").text.strip()

        
        release_year = "N/A"
        release_date = "N/A"
        json_ld = movie_soup.find('script', type='application/ld+json')
        if json_ld:
            movie_data = json.loads(json_ld.text)
            release_year = movie_data.get('datePublished', "N/A")[:4] if 'datePublished' in movie_data else "N/A"
            release_date = movie_data.get('datePublished', "N/A")

        
        rating_section = movie_soup.find("div", {"data-testid": "hero-rating-bar__aggregate-rating__score"})
        rating = rating_section.text.strip() if rating_section else "N/A"

        
        director = ", ".join([d['name'] for d in movie_data.get('director', [])]) if 'director' in movie_data else "N/A"
        genres = ", ".join(movie_data.get('genre', [])) if 'genre' in movie_data else "N/A"

        
        details_section = movie_soup.find("section", {"data-testid": "Details"})
        country, language, filming_locations = "N/A", "N/A", "N/A"

        if details_section:
           
            country_section = details_section.find("li", {"data-testid": "title-details-origin"})
            if country_section:
                country_links = country_section.find_all("a")
                countries = [link.text.strip() for link in country_links if link.text.strip()]
                country = ", ".join(countries) if countries else "N/A"

           
            language_section = details_section.find("li", {"data-testid": "title-details-languages"})
            if language_section:
                language_links = language_section.find_all("a")
                languages = [link.text.strip() for link in language_links if link.text.strip()]
                language = ", ".join(languages) if languages else "N/A"

            
            filming_locations_tag = details_section.find("li", {"data-testid": "title-details-filminglocations"})
            if filming_locations_tag:
                filming_locations = filming_locations_tag.text.strip()

       
        box_office_section = movie_soup.find("section", {"data-testid": "BoxOffice"})
        budget = "N/A"
        gross_revenue = "N/A"
        
        if box_office_section:
            budget_tag = box_office_section.find(string="Budget")
            budget = budget_tag.find_next("div").text.strip() if budget_tag else "N/A"

            gross_tag = box_office_section.find(string="Gross worldwide")
            gross_revenue = gross_tag.find_next("div").text.strip() if gross_tag else "N/A"

        
        official_sites_tag = movie_soup.find("li", {"data-testid": "details-officialsites"})
        official_sites = official_sites_tag.text.strip() if official_sites_tag else "N/A"

       
        production_companies = "N/A"
        production_section = details_section.find("li", {"data-testid": "title-details-companies"}) if details_section else None
        if production_section:
            production_links = production_section.find_all("a")
            companies = [link.text.strip() for link in production_links if link.text.strip()]
            production_companies = ", ".join(companies) if companies else "N/A"

       
        movies.append({
            "Movie_ID": movie_id,
            "Title": title,
            "Release Year": release_year,
            "Release Date": release_date,
            "Rating": rating,
            "Director(s)": director,
            "Genre(s)": genres,
            "Country of Origin": country,
            "Language": language,
            "Filming Locations": filming_locations,
            "Budget": budget,
            "Gross Worldwide Revenue": gross_revenue,
            "Official Sites": official_sites,
            "Production Companies": production_companies
        })

    except Exception as e:
        print(f"Error scraping {url}: {e}")

 
    time.sleep(2)  


movies_df = pd.DataFrame(movies)
movies_df.to_csv("imdb_top_250_movies.csv", index=False)

print(movies_df.head())
# Out:
#     Movie_ID                     Title Release Year Release Date  Rating  \
# 0  tt0111161  The Shawshank Redemption         1994   1994-10-14  9.3/10
# 1  tt0068646             The Godfather         1972   1972-03-24  9.2/10
# 2  tt0468569           The Dark Knight         2008   2008-07-18  9.0/10
# 3  tt0071562     The Godfather Part II         1974   1974-12-18  9.0/10
# 4  tt0050083              12 Angry Men         1957   1957-04-10  9.0/10
#
#             Director(s)              Genre(s)              Country of Origin  \
# 0        Frank Darabont                 Drama                  United States
# 1  Francis Ford Coppola          Crime, Drama                  United States
# 2     Christopher Nolan  Action, Crime, Drama  United States, United Kingdom
# 3  Francis Ford Coppola          Crime, Drama                  United States
# 4          Sidney Lumet          Crime, Drama                  United States
#
#                                      Language  \
# 0                                     English
# 1                     English, Italian, Latin
# 2                           English, Mandarin
# 3  English, Italian, Spanish, Latin, Sicilian
# 4                                     English
#
#                                    Filming Locations  \
# 0  Filming locationsMansfield Reformatory - 100 R...
# 1  Filming locationsForza d'Agrò, Messina, Sicily...
# 2            Filming locationsChicago, Illinois, USA
# 3  Filming locationsKaiser Estate - 4000 W Lake B...
# 4  Filming locationsNew York County Courthouse - ...
#
#                      Budget Gross Worldwide Revenue  \
# 0   $25,000,000 (estimated)             $29,332,133
# 1    $6,000,000 (estimated)            $250,342,198
# 2  $185,000,000 (estimated)          $1,009,053,678
# 3   $13,000,000 (estimated)             $47,964,222
# 4      $350,000 (estimated)                  $2,945
#
#                                       Official Sites  \
# 0  Official sitesOfficial FacebookWarner Bros. (U...
# 1  Official sitesOfficial FacebookOfficial Instagram
# 2                 Official sitesFacebookWarner Bros.
# 3    Official sitesOfficial FacebookOfficial Twitter
# 4                                                N/A
#
#                                 Production Companies
# 0      Production company, Castle Rock Entertainment
# 1  Production companies, Paramount Pictures, Albe...
# 2  Production companies, Warner Bros., Legendary ...
# 3  Production companies, Paramount Pictures, The ...
# 4         Production company, Orion-Nova Productions

# %% [markdown]
# # Task 2

# %% [markdown]
# ## Clean The Scraped Data

# %% [markdown]
# ### Clean The Imbd Table

# %%
import pandas as pd
import re


movies_df = pd.read_csv("imdb_top_250_movies.csv")


movies_df.fillna("N/A", inplace=True)


movies_df.drop_duplicates(inplace=True)


movies_df['Budget'] = movies_df['Budget'].apply(lambda x: re.sub(r'[^\d]', '', x) if x != "N/A" else x)
movies_df['Gross Worldwide Revenue'] = movies_df['Gross Worldwide Revenue'].apply(lambda x: re.sub(r'[^\d]', '', x) if x != "N/A" else x)


movies_df['Budget'] = pd.to_numeric(movies_df['Budget'], errors='coerce').fillna("N/A").astype(str)
movies_df['Gross Worldwide Revenue'] = pd.to_numeric(movies_df['Gross Worldwide Revenue'], errors='coerce').fillna("N/A").astype(str)


movies_df['Release Year'] = movies_df['Release Year'].apply(lambda x: str(x)[:4] if len(str(x)) > 4 else str(x))


for col in movies_df.select_dtypes(include=['object']):  
    movies_df[col] = movies_df[col].map(lambda x: x.strip() if isinstance(x, str) else x)


movies_df.to_csv("clean_imdb_top_250_movies.csv", index=False)


print(movies_df.head())
# Out:
#     Movie_ID                     Title Release Year Release Date  Rating  \
# 0  tt0111161  The Shawshank Redemption         1994   1994-10-14  9.3/10
# 1  tt0068646             The Godfather         1972   1972-03-24  9.2/10
# 2  tt0468569           The Dark Knight         2008   2008-07-18  9.0/10
# 3  tt0071562     The Godfather Part II         1974   1974-12-18  9.0/10
# 4  tt0050083              12 Angry Men         1957   1957-04-10  9.0/10
#
#             Director(s)              Genre(s)              Country of Origin  \
# 0        Frank Darabont                 Drama                  United States
# 1  Francis Ford Coppola          Crime, Drama                  United States
# 2     Christopher Nolan  Action, Crime, Drama  United States, United Kingdom
# 3  Francis Ford Coppola          Crime, Drama                  United States
# 4          Sidney Lumet          Crime, Drama                  United States
#
#                                      Language  \
# 0                                     English
# 1                     English, Italian, Latin
# 2                           English, Mandarin
# 3  English, Italian, Spanish, Latin, Sicilian
# 4                                     English
#
#                                    Filming Locations       Budget  \
# 0  Filming locationsMansfield Reformatory - 100 R...   25000000.0
# 1  Filming locationsForza d'Agrò, Messina, Sicily...    6000000.0
# 2            Filming locationsChicago, Illinois, USA  185000000.0
# 3  Filming locationsKaiser Estate - 4000 W Lake B...   13000000.0
# 4  Filming locationsNew York County Courthouse - ...     350000.0
#
#   Gross Worldwide Revenue                                     Official Sites  \
# 0              29332133.0  Official sitesOfficial FacebookWarner Bros. (U...
# 1             250342198.0  Official sitesOfficial FacebookOfficial Instagram
# 2            1009053678.0                 Official sitesFacebookWarner Bros.
# 3              47964222.0    Official sitesOfficial FacebookOfficial Twitter
# 4                  2945.0                                                N/A
#
#                                 Production Companies
# 0      Production company, Castle Rock Entertainment
# 1  Production companies, Paramount Pictures, Albe...
# 2  Production companies, Warner Bros., Legendary ...
# 3  Production companies, Paramount Pictures, The ...
# 4         Production company, Orion-Nova Productions

# %% [markdown]
# ### Clean The Crew Table

# %%
import pandas as pd


input_file = "full_cast_and_crew.csv"
output_file = "clean_full_cast_and_crew.csv"

try:
   
    df = pd.read_csv(input_file)

   
    print("Initial Data Preview:")
    print(df.head())
    print("\nData Info:")
    print(df.info())

    
    df = df.drop_duplicates()

    
    df['Character/Position'] = df['Character/Position'].fillna('Unknown')

    
    df.columns = [col.strip().replace(" ", "_").lower() for col in df.columns]

  
    df.rename(columns={'movie_id': 'Movie_ID'}, inplace=True)

    
    df['role_type'] = df['role_type'].str.title()

   
    string_columns = df.select_dtypes(include=['object']).columns
    df[string_columns] = df[string_columns].apply(lambda x: x.str.strip())

    
    df.to_csv(output_file, index=False)
    print(f"\nCleaned data saved to {output_file}")

except FileNotFoundError:
    print(f"File {input_file} not found. Ensure the file is in the correct directory.")
except Exception as e:
    print(f"An error occurred during processing: {e}")
# Out:
# Initial Data Preview:
#     Movie_ID            Name Role Type        Character/Position
# 0  tt0111161     Tim Robbins     Actor             Andy Dufresne
# 1  tt0111161  Morgan Freeman     Actor  Ellis Boyd 'Red' Redding
# 2  tt0111161      Bob Gunton     Actor             Warden Norton
# 3  tt0111161  William Sadler     Actor                   Heywood
# 4  tt0111161    Clancy Brown     Actor            Captain Hadley
#
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19290 entries, 0 to 19289
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie_ID            19290 non-null  object
#  1   Name                19290 non-null  object
#  2   Role Type           19290 non-null  object
#  3   Character/Position  19158 non-null  object
# dtypes: object(4)
# memory usage: 602.9+ KB
# None
#
# Cleaned data saved to clean_full_cast_and_crew.csv

# %% [markdown]
# # Transform The Data

# %% [markdown]
# ## Processing the imbd table

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler


input_file = "clean_imdb_top_250_movies.csv"
output_file = "processed_imdb_250_movies.csv"

print(f"Loading cleaned data from {input_file}...")


try:
    df = pd.read_csv(input_file)
    print("Data loaded successfully.")
except Exception as e:
    print(f"Error loading file: {e}")
    exit()


print("Data Overview Before Processing:")
print(df.info())
print(df.head())


def encode_categorical(df, column):
    le = LabelEncoder()
    df[column] = le.fit_transform(df[column].astype(str))
    return df


categorical_columns = ['Genre(s)', 'Country of Origin', 'Language', 'Production Companies']


for column in categorical_columns:
    if column in df.columns:
        df = encode_categorical(df, column)


numerical_columns = ['Rating', 'Budget', 'Gross Worldwide Revenue']


for column in numerical_columns:
    if column in df.columns:
        if df[column].isna().all(): 
            print(f"Warning: Column '{column}' contains all NaN values. It will be skipped in normalization.")
            
            df[column] = df[column].fillna(df[column].median())  

scaler = MinMaxScaler()
for column in numerical_columns:
    if column in df.columns and not df[column].isna().all():  # Check if column has valid data
        df[column] = scaler.fit_transform(df[[column]])




columns_to_standardize = ['Budget', 'Gross Worldwide Revenue']


for column in columns_to_standardize:
    if column in df.columns and df[column].isna().all():
        print(f"Warning: Column '{column}' contains all NaN values. It will be skipped in standardization.")
        df[column] = df[column].fillna(df[column].median())  # Fill NaN values with the median

scaler = StandardScaler()
for column in columns_to_standardize:
    if column in df.columns and not df[column].isna().all():  
        df[column] = scaler.fit_transform(df[[column]])


df[numerical_columns] = df[numerical_columns].fillna(df[numerical_columns].median())


for column in categorical_columns:
    if column in df.columns:
        df[column] = df[column].fillna("Unknown")

try:
    df.to_csv(output_file, index=False)
    print(f"Processed data saved successfully to {output_file}.")
except Exception as e:
    print(f"Error saving processed file: {e}")


print("Processed Data Overview:")
print(df.info())
print(df.head())
# Out:
# Loading cleaned data from clean_imdb_top_250_movies.csv...
# Data loaded successfully.
# Data Overview Before Processing:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Movie_ID                 250 non-null    object
#  1   Title                    250 non-null    object
#  2   Release Year             250 non-null    int64
#  3   Release Date             250 non-null    object
#  4   Rating                   250 non-null    object
#  5   Director(s)              250 non-null    object
#  6   Genre(s)                 250 non-null    object
#  7   Country of Origin        250 non-null    object
#  8   Language                 249 non-null    object
#  9   Filming Locations        234 non-null    object
#  10  Budget                   229 non-null    float64
#  11  Gross Worldwide Revenue  246 non-null    float64
#  12  Official Sites           180 non-null    object
#  13  Production Companies     249 non-null    object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 27.5+ KB
# None
#     Movie_ID                     Title  Release Year Release Date  Rating  \
# 0  tt0111161  The Shawshank Redemption          1994   1994-10-14  9.3/10
# 1  tt0068646             The Godfather          1972   1972-03-24  9.2/10
# 2  tt0468569           The Dark Knight          2008   2008-07-18  9.0/10
# 3  tt0071562     The Godfather Part II          1974   1974-12-18  9.0/10
# 4  tt0050083              12 Angry Men          1957   1957-04-10  9.0/10
#
#             Director(s)              Genre(s)              Country of Origin  \
# 0        Frank Darabont                 Drama                  United States
# 1  Francis Ford Coppola          Crime, Drama                  United States
# 2     Christopher Nolan  Action, Crime, Drama  United States, United Kingdom
# 3  Francis Ford Coppola          Crime, Drama                  United States
# 4          Sidney Lumet          Crime, Drama                  United States
#
#                                      Language  \
# 0                                     English
# 1                     English, Italian, Latin
# 2                           English, Mandarin
# 3  English, Italian, Spanish, Latin, Sicilian
# 4                                     English
#
#                                    Filming Locations       Budget  \
# 0  Filming locationsMansfield Reformatory - 100 R...   25000000.0
# 1  Filming locationsForza d'Agrò, Messina, Sicily...    6000000.0
# 2            Filming locationsChicago, Illinois, USA  185000000.0
# 3  Filming locationsKaiser Estate - 4000 W Lake B...   13000000.0
# 4  Filming locationsNew York County Courthouse - ...     350000.0
#
#    Gross Worldwide Revenue                                     Official Sites  \
# 0             2.933213e+07  Official sitesOfficial FacebookWarner Bros. (U...
# 1             2.503422e+08  Official sitesOfficial FacebookOfficial Instagram
# 2             1.009054e+09                 Official sitesFacebookWarner Bros.
# 3             4.796422e+07    Official sitesOfficial FacebookOfficial Twitter
# 4             2.945000e+03                                                NaN
#
#                                 Production Companies
# 0      Production company, Castle Rock Entertainment
# 1  Production companies, Paramount Pictures, Albe...
# 2  Production companies, Warner Bros., Legendary ...
# 3  Production companies, Paramount Pictures, The ...
# 4         Production company, Orion-Nova Productions
# ------------------------------------------------
# ValueError     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13560\2770594553.py in ?()
#      47
#      48 scaler = MinMaxScaler()
#      49 for column in numerical_columns:
#      50     if column in df.columns and not df[column].isna().all():  # Check if column has valid data
# ---> 51         df[column] = scaler.fit_transform(df[[column]])
#      52
#      53
#      54
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#     143             return_tuple = (
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#     911         # non-optimized default implementation; override when a better
#     912         # method is possible for a given clustering algorithm
#     913         if y is None:
#     914             # fit method of arity 1 (unsupervised transformation)
# --> 915             return self.fit(X, **fit_params).transform(X)
#     916         else:
#     917             # fit method of arity 2 (supervised transformation)
#     918             return self.fit(X, y, **fit_params).transform(X)
#
# ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y)
#     430             Fitted scaler.
#     431         """
#     432         # Reset internal state before fitting
#     433         self._reset()
# --> 434         return self.partial_fit(X, y)
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1147                 skip_parameter_validation=(
#    1148                     prefer_skip_nested_validation or global_skip_validation
#    1149                 )
#    1150             ):
# -> 1151                 return fit_method(estimator, *args, **kwargs)
#
# ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y)
#     468                 "Consider using MaxAbsScaler instead."
#     469             )
#     470
#     471         first_pass = not hasattr(self, "n_samples_seen_")
# --> 472         X = self._validate_data(
#     473             X,
#     474             reset=first_pass,
#     475             dtype=FLOAT_DTYPES,
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     600                 out = y
#     601             else:
#     602                 out = X, y
#     603         elif not no_val_X and no_val_y:
# --> 604             out = check_array(X, input_name="X", **check_params)
#     605         elif no_val_X and not no_val_y:
#     606             out = _check_y(y, **check_params)
#     607         else:
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     914                         )
#     915                     array = xp.astype(array, dtype, copy=False)
#     916                 else:
#     917                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 918             except ComplexWarning as complex_warning:
#     919                 raise ValueError(
#     920                     "Complex data not supported\n{}\n".format(array)
#     921                 ) from complex_warning
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp)
#     376         # Use NumPy API to support order
#     377         if copy is True:
#     378             array = numpy.array(array, order=order, dtype=dtype)
#     379         else:
# --> 380             array = numpy.asarray(array, order=order, dtype=dtype)
#     381
#     382         # At this point array is a NumPy ndarray. We convert it to an array
#     383         # container that is consistent with the input's namespace.
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, dtype)
#    1996     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    1997         values = self._values
# -> 1998         arr = np.asarray(values, dtype=dtype)
#    1999         if (
#    2000             astype_is_view(values.dtype, arr.dtype)
#    2001             and using_copy_on_write()
#
# ValueError: could not convert string to float: '9.3/10'

# %% [markdown]
# ## Integrate both Tables

# %%
import pandas as pd


imdb_df = pd.read_csv("processed_imdb_250_movies.csv")
cast_df = pd.read_csv('full_cast_and_crew.csv')


imdb_df.columns = imdb_df.columns.str.strip()
cast_df.columns = cast_df.columns.str.strip()


imdb_df['Movie_ID'] = imdb_df['Movie_ID'].str.strip().str.upper()
cast_df['Movie_ID'] = cast_df['Movie_ID'].str.strip().str.upper()


imdb_df = imdb_df.drop_duplicates(subset=['Movie_ID'])
cast_df = cast_df.drop_duplicates(subset=['Movie_ID', 'Name', 'Role Type', 'Character/Position'])


cast_df = cast_df[cast_df['Movie_ID'].isin(imdb_df['Movie_ID'])]

# Merge the datasets on 'Movie_ID' to simulate foreign key usage
merged_df = pd.merge(cast_df, imdb_df, on='Movie_ID', how='inner')


print("\nFirst 5 rows of Merged dataset (merged_df):")
print(merged_df.head(5))

merged_df.to_csv('merged_imdb_cast_and_crew.csv', index=False)
print("Merged dataset saved as 'merged_imdb_cast_and_crew.csv'")
# Out:
# First 5 rows of Merged dataset (merged_df):
#     Movie_ID            Name Role Type        Character/Position  \
# 0  TT0111161     Tim Robbins     Actor             Andy Dufresne
# 1  TT0111161  Morgan Freeman     Actor  Ellis Boyd 'Red' Redding
# 2  TT0111161      Bob Gunton     Actor             Warden Norton
# 3  TT0111161  William Sadler     Actor                   Heywood
# 4  TT0111161    Clancy Brown     Actor            Captain Hadley
#
#                       Title  Release Year Release Date  Rating  \
# 0  The Shawshank Redemption          1994   1994-10-14     NaN
# 1  The Shawshank Redemption          1994   1994-10-14     NaN
# 2  The Shawshank Redemption          1994   1994-10-14     NaN
# 3  The Shawshank Redemption          1994   1994-10-14     NaN
# 4  The Shawshank Redemption          1994   1994-10-14     NaN
#
#       Director(s)  Genre(s)  Country of Origin  Language  \
# 0  Frank Darabont        75                 46         4
# 1  Frank Darabont        75                 46         4
# 2  Frank Darabont        75                 46         4
# 3  Frank Darabont        75                 46         4
# 4  Frank Darabont        75                 46         4
#
#                                    Filming Locations    Budget  \
# 0  Filming locationsMansfield Reformatory - 100 R... -0.111628
# 1  Filming locationsMansfield Reformatory - 100 R... -0.111628
# 2  Filming locationsMansfield Reformatory - 100 R... -0.111628
# 3  Filming locationsMansfield Reformatory - 100 R... -0.111628
# 4  Filming locationsMansfield Reformatory - 100 R... -0.111628
#
#    Gross Worldwide Revenue                                     Official Sites  \
# 0                -0.540336  Official sitesOfficial FacebookWarner Bros. (U...
# 1                -0.540336  Official sitesOfficial FacebookWarner Bros. (U...
# 2                -0.540336  Official sitesOfficial FacebookWarner Bros. (U...
# 3                -0.540336  Official sitesOfficial FacebookWarner Bros. (U...
# 4                -0.540336  Official sitesOfficial FacebookWarner Bros. (U...
#
#    Production Companies
# 0                   181
# 1                   181
# 2                   181
# 3                   181
# 4                   181
# Merged dataset saved as 'merged_imdb_cast_and_crew.csv'

# %% [markdown]
# ## Connection to MySQL

# %%
from sqlalchemy import create_engine


username = 'root'            
password = 'Meera#04'  
host = 'localhost'           
port = '3306'               
database = 'mysql'  

engine = create_engine(f'mysql+pymysql://{username}:{password}@{host}:{port}/{database}')


try:
    connection = engine.connect()
    print("Connection to MySQL database established successfully!")
    connection.close()  
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Connection to MySQL database established successfully!

# %%
from sqlalchemy import create_engine


username = 'root'            
password = 'Meera#04'       
host = 'localhost'           
port = '3306'                


engine = create_engine(f'mysql+pymysql://{username}:{password}@{host}:{port}')


new_database = 'movie' 


try:
    with engine.connect() as connection:
        connection.execute(f"CREATE DATABASE IF NOT EXISTS {new_database};")
        print(f"Database '{new_database}' created successfully (or already exists).")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Database 'movie' created successfully (or already exists).

# %%
import pandas as pd
from sqlalchemy import create_engine

# Connection details
username = 'root'           
password = 'Meera#04'        
host = 'localhost'           
port = '3306'                
database = 'movie'           


csv_file = 'merged_imdb_cast_and_crew.csv'  
df = pd.read_csv(csv_file)


engine = create_engine(f'mysql+pymysql://{username}:{password}@{host}:{port}/{database}')


try:
    df.to_sql('imdb_data', con=engine, if_exists='replace', index=False)
    print("Data loaded successfully into the 'imdb_data' table.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Data loaded successfully into the 'imdb_data' table.
